# %%
import os
print(os.listdir(path))  # Run this first to see exact filename
# Out:
# ['pulsar_data_train.csv', 'pulsar_data_test.csv']

# %%
import pandas as pd
import kagglehub
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# Download dataset
path = kagglehub.dataset_download("colearninglounge/predicting-pulsar-starintermediate")
print("Dataset path:", path)

# Check exact filename
files = os.listdir(path)
print("Files available:", files)

# Auto-pick the CSV file
csv_file = [f for f in files if f.endswith('.csv')][0]
print("Using file:", csv_file)

# Load data
df = pd.read_csv(f"{path}/{csv_file}")
print(df.head())
print(df.columns.tolist())  # check column names too
# Out:
# Dataset path: /Users/bindhu/.cache/kagglehub/datasets/colearninglounge/predicting-pulsar-starintermediate/versions/1
# Files available: ['pulsar_data_train.csv', 'pulsar_data_test.csv']
# Using file: pulsar_data_train.csv
#     Mean of the integrated profile  \
# 0                       121.156250
# 1                        76.968750
# 2                       130.585938
# 3                       156.398438
# 4                        84.804688
#
#     Standard deviation of the integrated profile  \
# 0                                      48.372971
# 1                                      36.175557
# 2                                      53.229534
# 3                                      48.865942
# 4                                      36.117659
#
#     Excess kurtosis of the integrated profile  \
# 0                                    0.375485
# 1                                    0.712898
# 2                                    0.133408
# ...
